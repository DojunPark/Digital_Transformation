# %%
with open('C:/Users/dojun\Documents/api_keys/naver_api.txt') as f:
    client_id = f.readline().replace('\n', '')
    client_secret = f.readline()

# %%
import requests
import pandas as pd
import urllib.request
from urllib.request import quote
from urllib.parse import urlparse
from bs4 import BeautifulSoup as bs

keyword = '박경화'
url = 'https://openapi.naver.com/v1/search/book_adv.json?d_auth=' + keyword + '&display=15&start=1'
html = requests.get(url,headers = {"X-Naver-Client-Id" : client_id,
                                   "X-Naver-Client-Secret" : client_secret})

soup = bs(html.content, 'html.parser')

# %%
soup
# Out:
# {
# "lastBuildDate": "Tue, 02 Mar 2021 17:43:05 +0900",
# "total": 65,
# "start": 1,
# "display": 15,
# "items": [
# {
# "title": "고릴라는 핸드폰을 미워해 (아름다운 지구를 지키는 20가지 생각)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=6680681",
# "image": "https://bookthumb-phinf.pstatic.net/cover/066/806/06680681.jpg?type=m1&amp;udate;=20200415",
# "author": "<b>박경화</b>",
# "price": "12000",
# "discount": "10800",
# "publisher": "북센스",
# "pubdate": "20110715",
# "isbn": "8993746060 9788993746068",
# "description": "핸드폰, 세탁기, 냉장고, 나무젓가락, 화장지 등 우리 삶과 밀접한 물건들이 지구를 병들게 한다는 사실을 알고 있는가? 이 책은 일상에서 꼭 필요한 물건들이 지구의 환경과 미래에 어떤 폐해를 끼치고 있는지, 그리고 그 해결방법은 무엇인지를 알기 쉬운 언어로 흥미롭게 서술한 환경교양서이다.\n\n책은 우리... "
#
# },
# {
# "title": "동물가족화 (우리가족 닮은 동물 찾기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18032861",
# "image": "https://bookthumb-phinf.pstatic.net/cover/180/328/18032861.jpg?type=m1&amp;udate;=20210227",
# "author": "<b>박경화</b>",
# "price": "13000",
# "discount": "",
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

def get_idpw():
    with open('C:/Users/dojun/Documents/api_keys/naver_api.txt') as f:
        client_id = f.readline().replace('\n', '')
        client_secret = f.readline()
    return client_id, client_secret

def search_title(keyword, nid, npw):
    url = 'https://openapi.naver.com/v1/search/book.json?query=' + keyword + '&display=30&start=1'
    html = requests.get(url, headers={"X-Naver-Client-Id": nid,
                                      "X-Naver-Client-Secret": npw})
    json1 = html.json()
    df1 = pd.DataFrame(json1['items'], columns=['title', 'author', 'publisher', 'description'])
    return df1

def search_author(keyword, nid, npw):
    url = 'https://openapi.naver.com/v1/search/book_adv.json?d_auth=' + keyword + '&display=30&start=1'
    html = requests.get(url, headers={"X-Naver-Client-Id": nid,
                                      "X-Naver-Client-Secret": npw})
    json1 = html.json()
    df1 = pd.DataFrame(json1['items'], columns=['title', 'author', 'publisher', 'description'])
    return df1

# %%
tmp = search_title('파이썬', client_id, client_secret)

# %%
tmp
# Out:
#                                                 title             author  \
# 0   이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정...                나동빈
# 1   <b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, ...                김황후
# 2            혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)                윤인성
# 3                              Do it! 점프 투 <b>파이썬</b>                박응용
# 4   <b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 ...                박상길
# 5   <b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부...                권철민
# 6   혼자 공부하는 첫 프로그래밍 with <b>파이썬</b> (1:1 과외하듯 배우는 ...                문현일
# 7                모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)                이승찬
# 8   모두의 데이터 분석 with <b>파이썬</b> (실생활 예제로 시작하는 데이터 분...            송석리|이현아
# 9         Do it! 첫 <b>파이썬</b> (게임하듯 배우는 나의 첫 프로그래밍 책)             엘리스 코딩
# 10  <b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)                우재남
# 11  선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b> (선형대수와 통계...                장철원
# ...

# %%
type(tmp)
# Out:
# dict

# %%
pprint(tmp)
# Out:
# Pretty printing has been turned ON

# %%
tmp
# Out:
# {'lastBuildDate': 'Tue, 02 Mar 2021 19:06:51 +0900',
#  'total': 1235,
#  'start': 1,
#  'display': 30,
#  'items': [{'title': '이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드, C/C++, 자바 코드 제공)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16439154',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928',
#    'author': '나동빈',
#    'price': '34000',
#    'discount': '30600',
#    'publisher': '한빛미디어',
#    'pubdate': '20200805',
#    'isbn': '1162243074 9791162243077',
#    'description': '8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다.'},
#   {'title': '<b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, 트레이딩 전략, 자동 매매)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16381920',
# ...

# %%
tmp.keys()
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
tmp['items']
# Out:
# [{'title': '이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드, C/C++, 자바 코드 제공)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16439154',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928',
#   'author': '나동빈',
#   'price': '34000',
#   'discount': '30600',
#   'publisher': '한빛미디어',
#   'pubdate': '20200805',
#   'isbn': '1162243074 9791162243077',
#   'description': '8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다.'},
#  {'title': '<b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, 트레이딩 전략, 자동 매매)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16381920',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/163/819/16381920.jpg?type=m1&udate=20201117',
#   'author': '김황후',
#   'price': '32000',
#   'discount': '28800',
#   'publisher': '한빛미디어',
# ...

# %%
import pandas as pd

df1 = pd.DataFrame(tmp['items'], columns=['title', 'author', 'publisher', 'description'])

# %%
df1
# Out:
#                                                 title             author  \
# 0   이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정...                나동빈
# 1   <b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, ...                김황후
# 2            혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)                윤인성
# 3                              Do it! 점프 투 <b>파이썬</b>                박응용
# 4   <b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 ...                박상길
# 5   <b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부...                권철민
# 6   혼자 공부하는 첫 프로그래밍 with <b>파이썬</b> (1:1 과외하듯 배우는 ...                문현일
# 7                모두의 <b>파이썬</b> (20일 만에 배우는 프로그래밍 기초)                이승찬
# 8   모두의 데이터 분석 with <b>파이썬</b> (실생활 예제로 시작하는 데이터 분...            송석리|이현아
# 9         Do it! 첫 <b>파이썬</b> (게임하듯 배우는 나의 첫 프로그래밍 책)             엘리스 코딩
# 10  <b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)                우재남
# 11  선형대수와 통계학으로 배우는 머신러닝 with <b>파이썬</b> (선형대수와 통계...                장철원
# ...
