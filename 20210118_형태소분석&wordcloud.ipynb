# %% [markdown]
# # Okt

# %%
from konlpy.tag import Okt

okt = Okt()

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
with open('./py_data/2021_대통령_신년사.txt', 'r', encoding='utf-8') as f:
    txt = f.read()
    
words = okt.pos(txt)
words
# Out:
# [('존경', 'Noun'),
#  ('하는', 'Verb'),
#  ('국민', 'Noun'),
#  ('여러분', 'Noun'),
#  (',', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('신축년', 'Noun'),
#  ('새해', 'Noun'),
#  ('를', 'Josa'),
#  ('맞았습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('희망', 'Noun'),
#  ('을', 'Josa'),
#  ('기원', 'Noun'),
#  ('하면서도', 'Verb'),
#  ('마음', 'Noun'),
#  ('이', 'Josa'),
#  ('무겁습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('새해', 'Noun'),
#  ('가', 'Josa'),
#  ('새해', 'Noun'),
#  ('같지', 'Adjective'),
#  ('않다는', 'Verb'),
#  ('말', 'Noun'),
#  ('이', 'Josa'),
#  ('실감', 'Noun'),
#  ('납니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('코로나', 'Noun'),
#  ('와의', 'Josa'),
#  ('기나긴', 'Verb'),
#  ('전쟁', 'Noun'),
#  ('이', 'Josa'),
#  ('끝나지', 'Verb'),
#  ('않았습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('생명', 'Noun'),
#  ('과', 'Josa'),
#  ('안전', 'Noun'),
#  ('이', 'Josa'),
#  ('여전히', 'Adjective'),
#  ('위협', 'Noun'),
#  ('받고', 'Verb'),
#  (',', 'Punctuation'),
#  ('유례', 'Noun'),
#  ('없는', 'Adjective'),
#  ('민생', 'Noun'),
#  ('경제', 'Noun'),
#  ('의', 'Josa'),
#  ('어려움', 'Noun'),
#  ('이', 'Josa'),
#  ('지속', 'Noun'),
#  ('되고', 'Verb'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('일상', 'Noun'),
#  ('의', 'Josa'),
#  ('상실', 'Noun'),
#  ('로', 'Josa'),
#  ('겪는', 'Verb'),
#  ('아픔', 'Noun'),
#  ('도', 'Josa'),
#  ('계속', 'Noun'),
#  ('되고', 'Verb'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('고난', 'Noun'),
#  ('의', 'Josa'),
#  ('시기', 'Noun'),
#  ('를', 'Josa'),
#  ('건너고', 'Verb'),
#  ('계신', 'Adjective'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('께', 'Josa'),
#  ('깊은', 'Adjective'),
#  ('위로', 'Noun'),
#  ('의', 'Josa'),
#  ('말씀', 'Noun'),
#  ('을', 'Josa'),
#  ('드립니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('그러나', 'Conjunction'),
#  ('새해', 'Noun'),
#  ('는', 'Josa'),
#  ('분명히', 'Adjective'),
#  ('다른', 'Noun'),
#  ('해', 'Noun'),
#  ('가', 'Josa'),
#  ('될', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('는', 'Josa'),
#  ('함께', 'Adverb'),
#  ('코로나', 'Noun'),
#  ('를', 'Josa'),
#  ('이겨', 'Verb'),
#  ('낼', 'Noun'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('2021년', 'Number'),
#  ('은', 'Foreign'),
#  ('우리', 'Noun'),
#  ('국민', 'Noun'),
#  ('에게', 'Josa'),
#  ('‘', 'Foreign'),
#  ('회복', 'Noun'),
#  ('의', 'Josa'),
#  ('해', 'Noun'),
#  ('’,', 'Punctuation'),
#  ('‘', 'Foreign'),
#  ('포', 'Noun'),
#  ('용의', 'Noun'),
#  ('해', 'Noun'),
#  ('’,', 'Punctuation'),
#  ('‘', 'Foreign'),
#  ('도약', 'Noun'),
#  ('의', 'Josa'),
#  ('해', 'Noun'),
#  ('’', 'Punctuation'),
#  ('가', 'Verb'),
#  ('될', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('국민', 'Noun'),
#  ('여러분', 'Noun'),
#  (',', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('2020년', 'Number'),
#  (',', 'Punctuation'),
#  ('신종', 'Noun'),
#  ('감염병', 'Noun'),
#  ('이', 'Josa'),
#  ('인류', 'Noun'),
#  ('의', 'Josa'),
#  ('생명', 'Noun'),
#  ('을', 'Josa'),
#  ('위협', 'Noun'),
#  ('했고', 'Verb'),
#  (',', 'Punctuation'),
#  ('일상', 'Noun'),
#  ('은', 'Josa'),
#  ('송두리째', 'Noun'),
#  ('바뀌었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('또한', 'Noun'),
#  ('예외', 'Noun'),
#  ('가', 'Josa'),
#  ('아니었습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('세계', 'Noun'),
#  ('경제', 'Noun'),
#  ('도', 'Josa'),
#  ('대공황', 'Noun'),
#  ('이후', 'Noun'),
#  ('최악', 'Noun'),
#  ('의', 'Josa'),
#  ('침체', 'Noun'),
#  ('를', 'Josa'),
#  ('겪었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('경제', 'Noun'),
#  ('역시', 'Noun'),
#  ('마이너스', 'Noun'),
#  ('성장', 'Noun'),
#  ('을', 'Josa'),
#  ('면치', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('했습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('모두', 'Noun'),
#  ('가', 'Josa'),
#  ('어렵고', 'Adjective'),
#  ('힘들었습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('일', 'Noun'),
#  ('년', 'Noun'),
#  ('내내', 'Noun'),
#  ('불편', 'Noun'),
#  ('을', 'Josa'),
#  ('감수', 'Noun'),
#  ('해야', 'Verb'),
#  ('했습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('그러나', 'Conjunction'),
#  ('우리', 'Noun'),
#  ('는', 'Josa'),
#  ('꺾이지', 'Verb'),
#  ('않았습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('위기', 'Noun'),
#  ('속', 'Noun'),
#  ('에서', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('오히려', 'Noun'),
#  ('빛났습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('의료', 'Noun'),
#  ('진', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('헌신', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('환자', 'Noun'),
#  ('를', 'Josa'),
#  ('돌봤고', 'Verb'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('스스로', 'Noun'),
#  ('방역', 'Noun'),
#  ('의', 'Josa'),
#  ('주체', 'Noun'),
#  ('가', 'Josa'),
#  ('되었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('이웃', 'Noun'),
#  ('의', 'Josa'),
#  ('안전', 'Noun'),
#  ('이', 'Josa'),
#  ('곧', 'Noun'),
#  ('나', 'Noun'),
#  ('의', 'Josa'),
#  ('안전', 'Noun'),
#  ('이라는', 'Josa'),
#  ('지극히', 'Adverb'),
#  ('평범한', 'Adjective'),
#  ('진실', 'Noun'),
#  ('을', 'Josa'),
#  (',', 'Punctuation'),
#  ('놀라운', 'Adjective'),
#  ('실천', 'Noun'),
#  ('으로', 'Josa'),
#  ('전', 'Noun'),
#  ('세계', 'Noun'),
#  ('에', 'Josa'),
#  ('보여주었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('자발', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('구상', 'Noun'),
#  ('한', 'Josa'),
#  ('창의', 'Noun'),
#  ('적', 'Suffix'),
#  ('인', 'Josa'),
#  ('방역', 'Noun'),
#  ('조치', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('신속하게', 'Adjective'),
#  ('현장', 'Noun'),
#  ('에', 'Josa'),
#  ('적용', 'Noun'),
#  ('되었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('진단', 'Noun'),
#  ('키트', 'Noun'),
#  ('와', 'Josa'),
#  ('‘', 'Foreign'),
#  ('드라이브', 'Noun'),
#  ('스루', 'Noun'),
#  ('’', 'Punctuation'),
#  ('검사', 'Noun'),
#  ('방법', 'Noun'),
#  ('과', 'Josa'),
#  ('마스크', 'Noun'),
#  ('같은', 'Adjective'),
#  ('방역', 'Noun'),
#  ('물품', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('세계', 'Noun'),
#  ('각국', 'Noun'),
#  ('에', 'Josa'),
#  ('보급', 'Noun'),
#  ('되어', 'Verb'),
#  (',', 'Punctuation'),
#  ('인류', 'Noun'),
#  ('를', 'Josa'),
#  ('코로나', 'Noun'),
#  ('로부터', 'Noun'),
#  ('지키는데', 'Verb'),
#  ('크게', 'Noun'),
#  ('기여', 'Noun'),
#  ('했습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('‘', 'Foreign'),
#  ('K', 'Alpha'),
#  ('-', 'Punctuation'),
#  ('방역', 'Noun'),
#  ('’', 'Punctuation'),
#  ('은', 'Noun'),
#  ('국민', 'Noun'),
#  ('한', 'Verb'),
#  ('사람', 'Noun'),
#  ('한', 'Verb'),
#  ('사람', 'Noun'),
#  ('의', 'Josa'),
#  ('헌신', 'Noun'),
#  ('과', 'Josa'),
#  ('희생', 'Noun'),
#  ('위', 'Noun'),
#  ('에', 'Josa'),
#  ('세워진', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('세계', 'Noun'),
#  ('최초', 'Noun'),
#  ('로', 'Josa'),
#  ('전국', 'Noun'),
#  ('단위', 'Noun'),
#  ('선거', 'Noun'),
#  ('와', 'Josa'),
#  ('입시', 'Noun'),
#  ('를', 'Josa'),
#  ('치러', 'Verb'),
#  ('냈고', 'Verb'),
#  (',', 'Punctuation'),
#  ('봉쇄', 'Noun'),
#  ('없이', 'Adverb'),
#  ('확산', 'Noun'),
#  ('을', 'Josa'),
#  ('최대한', 'Noun'),
#  ('억제', 'Noun'),
#  ('하며', 'Verb'),
#  (',', 'Punctuation'),
#  ('OECD', 'Alpha'),
#  ('국가', 'Noun'),
#  ('중', 'Noun'),
#  ('에서도', 'Josa'),
#  ('손꼽히는', 'Verb'),
#  ('방역', 'Noun'),
#  ('모범', 'Noun'),
#  ('국가', 'Noun'),
#  ('가', 'Josa'),
#  ('된', 'Verb'),
#  ('것', 'Noun'),
#  ('은', 'Josa'),
#  (',', 'Punctuation'),
#  ('우리', 'Noun'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('만들어', 'Verb'),
#  ('낸', 'Verb'),
#  (',', 'Punctuation'),
#  ('누구', 'Noun'),
#  ('도', 'Josa'),
#  ('깎아', 'Verb'),
#  ('내릴', 'Verb'),
#  ('수', 'Noun'),
#  ('없는', 'Adjective'),
#  ('소중한', 'Adjective'),
#  ('성과', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('의', 'Josa'),
#  ('상생', 'Noun'),
#  ('정신', 'Noun'),
#  ('은', 'Josa'),
#  ('경제', 'Noun'),
#  ('위기', 'Noun'),
#  ('를', 'Josa'),
#  ('극복', 'Noun'),
#  ('하는', 'Verb'),
#  ('데', 'Noun'),
#  ('에도', 'Josa'),
#  ('가장', 'Noun'),
#  ('큰', 'Verb'),
#  ('힘', 'Noun'),
#  ('이', 'Josa'),
#  ('되었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('‘', 'Foreign'),
#  ('착한', 'Adjective'),
#  ('임대료', 'Noun'),
#  ('운동', 'Noun'),
#  ('’', 'Punctuation'),
#  ('을', 'Josa'),
#  ('시작', 'Noun'),
#  ('으로', 'Josa'),
#  ('‘', 'Foreign'),
#  ('착한', 'Adjective'),
#  ('선', 'Noun'),
#  ('결제', 'Noun'),
#  ('운동', 'Noun'),
#  ('’', 'Punctuation'),
#  ('과', 'Noun'),
#  ('‘', 'Foreign'),
#  ('농산물', 'Noun'),
#  ('꾸러미', 'Noun'),
#  ('운동', 'Noun'),
#  ('’', 'Punctuation'),
#  ('이', 'Noun'),
#  ('이어졌고', 'Verb'),
#  (',', 'Punctuation'),
#  ('어려움', 'Noun'),
#  ('을', 'Josa'),
#  ('겪고', 'Verb'),
#  ('있는', 'Adjective'),
#  ('이웃', 'Noun'),
#  ('들', 'Suffix'),
#  ('과', 'Josa'),
#  ('‘', 'Foreign'),
#  ('함께', 'Adverb'),
#  ('사는', 'Verb'),
#  ('길', 'Noun'),
#  ('’', 'Punctuation'),
#  ('을', 'Josa'),
#  ('찾았습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('노동자', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('경제', 'Noun'),
#  ('위기', 'Noun'),
#  ('극복', 'Noun'),
#  ('에', 'Josa'),
#  ('앞장섰고', 'Verb'),
#  (',', 'Punctuation'),
#  ('기업', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('최대한', 'Noun'),
#  ('고용', 'Noun'),
#  ('을', 'Josa'),
#  ('유지', 'Noun'),
#  ('해', 'Verb'),
#  ('주었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('경제', 'Noun'),
#  ('는', 'Josa'),
#  ('지난해', 'Noun'),
#  ('OECD', 'Alpha'),
#  ('국가', 'Noun'),
#  ('중', 'Noun'),
#  ('최고', 'Noun'),
#  ('의', 'Josa'),
#  ('성장', 'Noun'),
#  ('률', 'Noun'),
#  ('로', 'Josa'),
#  (',', 'Punctuation'),
#  ('GDP', 'Alpha'),
#  ('규모', 'Noun'),
#  ('세계', 'Noun'),
#  ('10', 'Number'),
#  ('위', 'Noun'),
#  ('권', 'Suffix'),
#  ('안', 'Noun'),
#  ('으로', 'Josa'),
#  ('진입', 'Noun'),
#  ('할', 'Verb'),
#  ('전망', 'Noun'),
#  ('이며', 'Josa'),
#  (',', 'Punctuation'),
#  ('1', 'Number'),
#  ('인당', 'Verb'),
#  ('국민소득', 'Noun'),
#  ('또한', 'Noun'),
#  ('사상', 'Noun'),
#  ('처음', 'Noun'),
#  ('으로', 'Josa'),
#  ('G', 'Alpha'),
#  ('7', 'Number'),
#  ('국가', 'Noun'),
#  ('를', 'Josa'),
#  ('넘어설', 'Verb'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('예측', 'Noun'),
#  ('됩니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('주가지수', 'Noun'),
#  ('역시', 'Noun'),
#  ('2,000', 'Number'),
#  ('선', 'Noun'),
#  ('돌파', 'Noun'),
#  ('14년', 'Number'),
#  ('만에', 'Josa'),
#  ('주가', 'Noun'),
#  ('3,000시', 'Number'),
#  ('대를', 'Foreign'),
#  ('열', 'Noun'),
#  ('며', 'Josa'),
#  ('OECD', 'Alpha'),
#  ('국가', 'Noun'),
#  ('중', 'Noun'),
#  ('가장', 'Noun'),
#  ('높은', 'Adjective'),
#  ('주가', 'Noun'),
#  ('상', 'Noun'),
#  ('승률', 'Noun'),
#  ('을', 'Josa'),
#  ('기록', 'Noun'),
#  ('했고', 'Verb'),
#  (',', 'Punctuation'),
#  ('위기', 'Noun'),
#  ('속', 'Noun'),
#  ('에서도', 'Josa'),
#  ('한국', 'Noun'),
#  ('경제', 'Noun'),
#  ('의', 'Josa'),
#  ('미래', 'Noun'),
#  ('전망', 'Noun'),
#  ('이', 'Josa'),
#  ('밝', 'Verb'),
#  ('음', 'Noun'),
#  ('을', 'Josa'),
#  ('보여주고', 'Verb'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('결코', 'Noun'),
#  ('멈추지', 'Verb'),
#  ('않았습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('국민', 'Noun'),
#  ('모두', 'Noun'),
#  ('어려움', 'Noun'),
#  ('속', 'Noun'),
#  ('에서', 'Josa'),
#  ('최선', 'Noun'),
#  ('을', 'Josa'),
#  ('다', 'Adverb'),
#  ('하며', 'Verb'),
#  ('위기', 'Noun'),
#  ('에', 'Josa'),
#  ('강한', 'Adjective'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('저력', 'Noun'),
#  ('을', 'Josa'),
#  ('보여주었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('이제', 'Noun'),
#  ('는', 'Josa'),
#  ('드디어', 'Adverb'),
#  ('어', 'Noun'),
#  ('두운', 'Noun'),
#  ('터널', 'Noun'),
#  ('의', 'Josa'),
#  ('끝', 'Noun'),
#  ('이', 'Josa'),
#  ('보입니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('불확실', 'Noun'),
#  ('성', 'Suffix'),
#  ('들이', 'Verb'),
#  ('많이', 'Adverb'),
#  ('걷혀', 'Verb'),
#  (',', 'Punctuation'),
#  ('이제', 'Noun'),
#  ('는', 'Josa'),
#  ('예측', 'Noun'),
#  ('하고', 'Josa'),
#  ('전망', 'Noun'),
#  ('하며', 'Verb'),
#  ('계획', 'Noun'),
#  ('을', 'Josa'),
#  ('세울', 'Verb'),
#  ('수', 'Noun'),
#  ('있게', 'Adjective'),
#  ('되었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('올해', 'Noun'),
#  ('우리', 'Noun'),
#  ('는', 'Josa'),
#  ('온전히', 'Verb'),
#  ('일상', 'Noun'),
#  ('을', 'Josa'),
#  ('회복하고', 'Adjective'),
#  ('빠르고', 'Adjective'),
#  ('강한', 'Adjective'),
#  ('경', 'Modifier'),
#  ('제', 'Modifier'),
#  ('회복', 'Noun'),
#  ('으로', 'Josa'),
#  ('새로운', 'Adjective'),
#  ('시대', 'Noun'),
#  ('의', 'Josa'),
#  ('선도', 'Noun'),
#  ('국가', 'Noun'),
#  ('로', 'Josa'),
#  ('도약', 'Noun'),
#  ('할', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('하지만', 'Conjunction'),
#  ('국가', 'Noun'),
#  ('경제', 'Noun'),
#  ('가', 'Josa'),
#  ('나아지더라도', 'Verb'),
#  (',', 'Punctuation'),
#  ('고용', 'Noun'),
#  ('을', 'Josa'),
#  ('회복하고', 'Adjective'),
#  ('소상', 'Noun'),
#  ('공인', 'Noun'),
#  ('·', 'Punctuation'),
#  ('자영', 'Noun'),
#  ('업자', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('입은', 'Verb'),
#  ('타격', 'Noun'),
#  ('을', 'Josa'),
#  ('회복하는', 'Adjective'),
#  ('데', 'Noun'),
#  ('는', 'Josa'),
#  ('더', 'Noun'),
#  ('많은', 'Adjective'),
#  ('시간', 'Noun'),
#  ('이', 'Josa'),
#  ('걸릴', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('코로나', 'Noun'),
#  ('로', 'Josa'),
#  ('더', 'Noun'),
#  ('깊어진', 'Adjective'),
#  ('격차', 'Noun'),
#  ('를', 'Josa'),
#  ('줄이는', 'Verb'),
#  ('포', 'Noun'),
#  ('용적', 'Noun'),
#  ('인', 'Josa'),
#  ('회복', 'Noun'),
#  ('을', 'Josa'),
#  ('이루는', 'Verb'),
#  ('것', 'Noun'),
#  ('이', 'Josa'),
#  ('무엇', 'Noun'),
#  ('보다', 'Josa'),
#  ('중요합니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('국민', 'Noun'),
#  ('여러분', 'Noun'),
#  (',', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('마스크', 'Noun'),
#  ('에서', 'Josa'),
#  ('해방', 'Noun'),
#  ('되는', 'Verb'),
#  ('평범한', 'Adjective'),
#  ('일상', 'Noun'),
#  ('으로', 'Josa'),
#  ('빠르게', 'Adjective'),
#  ('돌아가는', 'Verb'),
#  ('것', 'Noun'),
#  ('이', 'Josa'),
#  ('급선무', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('점차', 'Noun'),
#  ('나아지고', 'Verb'),
#  ('있는', 'Adjective'),
#  ('방역', 'Noun'),
#  ('의', 'Josa'),
#  ('마지막', 'Noun'),
#  ('고비', 'Noun'),
#  ('를', 'Josa'),
#  ('잘', 'Verb'),
#  ('넘기는', 'Verb'),
#  ('것', 'Noun'),
#  ('이', 'Josa'),
#  ('우선', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('정부', 'Noun'),
#  ('는', 'Josa'),
#  ('국민', 'Noun'),
#  ('과', 'Josa'),
#  ('함께', 'Adverb'),
#  ('3', 'Number'),
#  ('차', 'Noun'),
#  ('유행', 'Noun'),
#  ('을', 'Josa'),
#  ('조기', 'Noun'),
#  ('에', 'Josa'),
#  ('끝낼', 'Verb'),
#  ('수', 'Noun'),
#  ('있도록', 'Adjective'),
#  ('최선', 'Noun'),
#  ('을', 'Josa'),
#  ('다', 'Adverb'),
#  ('하겠습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('다음', 'Noun'),
#  ('달이', 'Noun'),
#  ('면', 'Josa'),
#  (',', 'Punctuation'),
#  ('백신', 'Noun'),
#  ('접종', 'Noun'),
#  ('을', 'Josa'),
#  ('시작', 'Noun'),
#  ('할', 'Verb'),
#  ('수', 'Noun'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('우선', 'Noun'),
#  ('순위', 'Noun'),
#  ('에', 'Josa'),
#  ('따라', 'Verb'),
#  ('순서대로', 'Noun'),
#  ('전', 'Noun'),
#  ('국민', 'Noun'),
#  ('이', 'Josa'),
#  ('무료', 'Noun'),
#  ('로', 'Josa'),
#  ('접종', 'Noun'),
#  ('받을', 'Verb'),
#  ('수', 'Noun'),
#  ('있도록', 'Adjective'),
#  ('하겠습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('기업', 'Noun'),
#  ('이', 'Josa'),
#  ('개발', 'Noun'),
#  ('한', 'Josa'),
#  ('치료', 'Noun'),
#  ('제의', 'Noun'),
#  ('심사', 'Noun'),
#  ('도', 'Josa'),
#  ('진행', 'Noun'),
#  ('중', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('안전성', 'Noun'),
#  ('의', 'Josa'),
#  ('검사', 'Noun'),
#  ('와', 'Josa'),
#  ('허가', 'Noun'),
#  (',', 'Punctuation'),
#  ('사용', 'Noun'),
#  ('과', 'Josa'),
#  ('효과', 'Noun'),
#  ('에', 'Josa'),
#  ('이르기까지', 'Verb'),
#  ('전', 'Noun'),
#  ('과정', 'Noun'),
#  ('을', 'Josa'),
#  ('투명하게', 'Adjective'),
#  ('공개', 'Noun'),
#  ('하겠습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('자체', 'Noun'),
#  ('적', 'Suffix'),
#  ('인', 'Josa'),
#  ('백신', 'Noun'),
#  ('개발', 'Noun'),
#  ('도', 'Josa'),
#  ('계속', 'Noun'),
#  ('독려', 'Noun'),
#  ('할', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('백신', 'Noun'),
#  ('자주권', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('하여', 'Verb'),
#  (',', 'Punctuation'),
#  ('우리', 'Noun'),
#  ('국민', 'Noun'),
#  ('의', 'Josa'),
#  ('안전', 'Noun'),
#  ('과', 'Josa'),
#  ('국제', 'Noun'),
#  ('보건', 'Noun'),
#  ('협력', 'Noun'),
#  ('을', 'Josa'),
#  ('강화하는데', 'Adjective'),
#  ('기여', 'Noun'),
#  ('할', 'Verb'),
#  ('수', 'Noun'),
#  ('있도록', 'Adjective'),
#  ('하겠습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('경제', 'Noun'),
#  ('에서도', 'Josa'),
#  ('빠르고', 'Adjective'),
#  ('강한', 'Adjective'),
#  ('회복', 'Noun'),
#  ('을', 'Josa'),
#  ('이룰', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('이미', 'Adverb'),
#  ('우리', 'Noun'),
#  ('경제', 'Noun'),
#  ('는', 'Josa'),
#  ('지난해', 'Noun'),
#  ('3분', 'Number'),
#  ('기부터', 'Foreign'),
#  ('플러스', 'Noun'),
#  ('성장', 'Noun'),
#  ('으로', 'Josa'),
#  ('전환', 'Noun'),
#  ('했습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('지난해', 'Noun'),
#  ('12월', 'Number'),
#  ('수출', 'Noun'),
#  ('은', 'Josa'),
#  ('2년', 'Number'),
#  ('만에', 'Josa'),
#  ('500억', 'Number'),
#  ('달러', 'Noun'),
#  ('를', 'Josa'),
#  ('넘었고', 'Verb'),
#  ('12월', 'Number'),
#  ('기준', 'Noun'),
#  ('으로는', 'Josa'),
#  ('역대', 'Noun'),
#  ('최고', 'Noun'),
#  ('치를', 'Verb'),
#  ('기록', 'Noun'),
#  ('했습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('이', 'Noun'),
#  ('기세', 'Noun'),
#  ('를', 'Josa'),
#  ('이어', 'Verb'),
#  ('우리', 'Noun'),
#  ('경제', 'Noun'),
#  ('는', 'Josa'),
#  ('올해', 'Noun'),
#  ('상반기', 'Noun'),
#  ('에', 'Josa'),
#  ('코로나', 'Noun'),
#  ('이전', 'Noun'),
#  ('수준', 'Noun'),
#  ('을', 'Josa'),
#  ('회복하게', 'Adjective'),
#  ('될', 'Verb'),
#  ('것', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('민생', 'Noun'),
#  ('경제', 'Noun'),
#  ('에서는', 'Josa'),
#  ('코로나', 'Noun'),
#  ('3', 'Number'),
#  ('차', 'Noun'),
#  ('확산', 'Noun'),
#  ('의', 'Josa'),
#  ('피해', 'Noun'),
#  ('업종', 'Noun'),
#  ('과', 'Josa'),
#  ('계층', 'Noun'),
#  ('을', 'Josa'),
#  ('지원', 'Noun'),
#  ('하기', 'Verb'),
#  ('위해', 'Noun'),
#  (',', 'Punctuation'),
#  ('오늘', 'Noun'),
#  ('부터', 'Josa'),
#  ('280만', 'Number'),
#  ('명의', 'Noun'),
#  ('소상', 'Noun'),
#  ('공인', 'Noun'),
#  (',', 'Punctuation'),
#  ('자영', 'Noun'),
#  ('업자', 'Noun'),
#  ('와', 'Josa'),
#  ('특수', 'Noun'),
#  ('고용', 'Noun'),
#  ('직', 'Noun'),
#  (',', 'Punctuation'),
#  ('프리랜서', 'Noun'),
#  (',', 'Punctuation'),
#  ('돌봄', 'Verb'),
#  ('종사', 'Noun'),
#  ('자', 'Suffix'),
#  ('를', 'Josa'),
#  ('비롯', 'Noun'),
#  ('한', 'Josa'),
#  ('87만', 'Number'),
#  ('명의', 'Noun'),
#  ('고용', 'Noun'),
#  ('취약', 'Noun'),
#  ('계층', 'Noun'),
#  ('에게', 'Josa'),
#  ('3', 'Number'),
#  ('차', 'Noun'),
#  ('재난', 'Noun'),
#  ('지', 'Josa'),
#  ('원금', 'Noun'),
#  ('을', 'Josa'),
#  ('지급', 'Noun'),
#  ('합니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('충분하지', 'Adjective'),
#  ('않은', 'Verb'),
#  ('줄', 'Noun'),
#  ('알', 'Noun'),
#  ('지만', 'Josa'),
#  ('민생', 'Noun'),
#  ('경제', 'Noun'),
#  ('의', 'Josa'),
#  ('회복', 'Noun'),
#  ('을', 'Josa'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('마중', 'Noun'),
#  ('물이', 'Noun'),
#  ('되', 'Verb'),
#  ('기를', 'Verb'),
#  ('기대합니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('정부', 'Noun'),
#  ('는', 'Josa'),
#  ('이', 'Noun'),
#  ('에', 'Josa'),
#  ('그치지', 'Verb'),
#  ('않고', 'Verb'),
#  ...]

# %%
ls_adj = [word[0] for word in words if word[1] == 'Adjective']
ls_adv = [word[0] for word in words if word[1] == 'Adverb']
ls_noun = [word[0] for word in words if word[1] == 'Noun']

# %%
print(len(ls_adj))
print(ls_adj[:100])
# Out:
# 214
# ['무겁습니다', '같지', '여전히', '없는', '있습니다', '있습니다', '계신', '깊은', '분명히', '입니다', '입니다', '입니다', '아니었습니다', '어렵고', '힘들었습니다', '평범한', '놀라운', '신속하게', '같은', '입니다', '없는', '소중한', '입니다', '착한', '착한', '있는', '높은', '있습니다', '강한', '있게', '회복하고', '빠르고', '강한', '새로운', '입니다', '회복하고', '회복하는', '많은', '입니다', '깊어진', '중요합니다', '평범한', '빠르게', '입니다', '있는', '입니다', '있도록', '있습니다', '있도록', '입니다', '투명하게', '입니다', '강화하는데', '있도록', '빠르고', '강한', '입니다', '회복하게', '입니다', '충분하지', '기대합니다', '있도록', '신속하게', '있게', '입니다', '입니다', '있는', '입니다', '있다는', '있게', '수월해', '있었습니다', '부족합니다', '입니다', '필요한', '특별히', '빠르게', '있는', '다양한', '신속히', '인해', '빠르게', '있습니다', '있습니다', '치열해질', '입니다', '입니다', '같은', '있습니다', '새로운', '빠르게', '자리매', '있습니다', '꾸준히', '있습니다', '입니다', '빨라질', '입니다', '새로운', '있습니다']

# %%
print(len(ls_adv))
print(ls_adv[:100])
# Out:
# 35
# ['함께', '지극히', '없이', '함께', '다', '드디어', '많이', '함께', '다', '이미', '특히', '함께', '함께', '함께', '함께', '그만큼', '아직', '함께', '히', '함께', '오랜', '오랜', '함께', '함께', '함께', '없이', '다', '함께', '다', '함께', '함께', '특히', '같이', '어느', '함께']

# %%
print(len(ls_noun))
print(ls_noun[:100])
# Out:
# 1541
# ['존경', '국민', '여러분', '신축년', '새해', '희망', '기원', '마음', '새해', '새해', '말', '실감', '코로나', '전쟁', '생명', '안전', '위협', '유례', '민생', '경제', '어려움', '지속', '일상', '상실', '아픔', '계속', '고난', '시기', '국민', '위로', '말씀', '새해', '다른', '해', '것', '우리', '코로나', '낼', '것', '우리', '국민', '회복', '해', '포', '용의', '해', '도약', '해', '것', '국민', '여러분', '신종', '감염병', '인류', '생명', '위협', '일상', '송두리째', '우리', '또한', '예외', '세계', '경제', '대공황', '이후', '최악', '침체', '우리', '경제', '역시', '마이너스', '성장', '면치', '모두', '국민', '일', '년', '내내', '불편', '감수', '우리', '위기', '속', '대한민국', '오히려', '의료', '진', '헌신', '환자', '국민', '스스로', '방역', '주체', '우리', '국민', '이웃', '안전', '곧', '나', '안전']

# %%
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
import matplotlib.pyplot as plt
import nltk

with open('./py_data/2021_대통령_신년사.txt', 'r', encoding='utf-8') as f:
    txt = f.read()

stop_words = ['가야', '갈수록', '결코', '그동안', '다른', '달이', '대한', '두운', '또한', '로부터', '만큼', '면치', '물이',
             '보이', '스루', '위해', '헛되', '우리']

words = okt.pos(txt)
ls_noun = [word[0] for word in words if (word[1] == 'Noun') & (len(word[0])>1) & (word[0] not in stop_words)]

counts = Counter(ls_noun)

wordcloud = WordCloud(font_path = 'C:\Windows\Fonts\HMKMRHD.TTF',
                      background_color = 'black', 
                      width = 1000, height = 1000,
                      max_words = 500,
                      max_font_size = 300)

wc = wordcloud.generate_from_frequencies(counts)
plt.figure(figsize = (12, 12))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')

plt.savefig('./py_data/wordcloud/신년사_워드클라우드.jpg')
plt.show()

# %%
import pandas as pd

count_sorted = counts.most_common()
df = pd.DataFrame(count_sorted, columns=['단어', '빈도수'])
df.to_csv('./py_data/wordcloud/신년사_단어빈도수.csv', encoding='euc-kr')

df[:15]
# Out:
#      단어  빈도수
# 0    국민   32
# 1    경제   26
# 2   코로나   16
# 3    국가   16
# 4    협력   14
# 5    세계   12
# 6   지난해   12
# 7    안전   11
# 8    위기   11
# 9    고용   11
# 10   뉴딜   11
# 11   회복   10
# 12   정부   10
# 13   상생    9
# 14   지역    9

# %%
import matplotlib.font_manager as fm

df2 = df[:10]

font_path = 'C:\Windows\Fonts\HMKMRHD.TTF'
fontprop = fm.FontProperties(fname = font_path, size = 15).get_name()
# plt.rc('font', family = fontprop)
plt.rcParams["font.family"] = fontprop
plt.rcParams["figure.figsize"] = (10,10)
plt.rcParams["font.size"] = 20

explode = [0, 0, 0.5, 0, 0, 0, 0, 0, 0, 0]

plt.pie(df2['빈도수'], labels=df2['단어'], autopct = '%.1f%%',
       startangle = 120, counterclock = False, explode = explode)

plt.show()
