# %% [markdown]
# # 네이버 리뷰 크롤링
# - `.getText()`: 하위 태그를 제거하고 유니코드 텍스트 문자열만 반환
# - `.text`: 하위 태그의 텍스트까지 문자열로 반환
# - `.string`: 태그 하위 문자열을 객체화

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re
from tqdm import tqdm
import time
from datetime import date

# base url
url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=163834&type=after&onlyActualPointYn=N&onlySpoilerPointYn=N&order=newest&page='

# 정규표현식
regex = re.compile('.*_filtered_ment_.*')

# 페이지 반복
ls_comments = []
for p in tqdm(range(1, 419), desc='crawling...'):
    time.sleep(0.5)
    
    p_url = url + str(p)
    html = requests.get(p_url)
    soup = bs(html.content, 'html.parser')
    
    stars = soup.find_all('div', class_='star_score')
    div = soup.find_all('div', class_='score_reple')

    # 댓글 추출
    for s, d in zip(stars, div):
        score = s.find('em').text
        
        dt = d.select('dt > em')[-1].text[:10]
        year = int(dt[:4])
        month = int(dt[5:7])
        day = int(dt[8:10])
        dates = date(year, month, day)
        
        r = d.find('span', {'id':regex})
        try:
            comment = r.find('a')['data-src']
        except:
            comment = re.sub('[\r\n\t]', '', r.text)
            
        ls_comments.append([dates, int(score), comment])
# Out:
# crawling...: 100%|███████████████████████████████████████████████████████████████████| 418/418 [04:24<00:00,  1.58it/s]

# %%
# 데이터 프레임 변환
df = pd.DataFrame(ls_comments, columns=['날짜', '점수', '댓글'])
df.head()
# Out:
#            날짜  점수                                                 댓글
# 0  2021-01-19   4  탁당이 More More하면서 원더우먼과 대치할때 수어사이드 스쿼드의 엉덩이 춤의 ...
# 1  2021-01-19   1                                         DC가 DC했다.
# 2  2021-01-19   1  원더 우먼이라는 캐릭터 자체가 별다른 매력없이 소비되고, 흥미롭게 시작하는 첫부분은...
# 3  2021-01-19  10  오락영화가 이정도면 괜찮을듯한데... 스토리도 괜찮았음.  갤가돗은 예뻤고.. 마블...
# 4  2021-01-19   1                                진짜 보다가 잤음 노젬 돈 아까움

# %%
# 파일 저장
df.to_excel('./py_data/crawling/원더우먼_리뷰.xlsx', index=False, encoding='euc-kr', engine='openpyxl')

# %% [markdown]
# # 형태소 분석

# %%
import pandas as pd

df = pd.read_excel('./py_data/crawling/원더우먼_리뷰.xlsx', engine='openpyxl')

txt = ''
for i, r in df.iterrows():
    try:
        txt += r[2]
        txt += '\n'
    except:
        continue

# %%
txt.count('겔 가돗')
# Out:
# 9

# %%
txt
# Out:
# '탁당이 More More하면서 원더우먼과 대치할때 수어사이드 스쿼드의 엉덩이 춤의 악몽이 떠오르더군요. DC는 대본과 연출이 마블대비 고루한 것 같아요. 보통 미드의 작가진은 탄탄하던데 DC영화 작가진은 어설픈것 같아 안타깝습니다. 수어사이드 스쿼드, 샤잠...저스티스리그는 조금 낫긴했는데...아쉽게도 마블과 너무 대비되네요. 재미있는 DC 영화가 나오길 아직 기다려봅니다. \nDC가 DC했다. \n원더 우먼이라는 캐릭터 자체가 별다른 매력없이 소비되고, 흥미롭게 시작하는 첫부분은 영화와는 전혀 무관한 별개의 스토리로 흘러간다. 말로 설득되는 시시한 악당 한명과 이빨승부를 하는 원더우먼, 뜬금없는 호랭인간...모든면에서 부족하고 흥미롭지 않은 유아용영화 \n오락영화가 이정도면 괜찮을듯한데... 스토리도 괜찮았음.  갤가돗은 예뻤고.. 마블기준으로 가오갤이나 토르3 윈터솔져보다는 많이 안좋지만... 캡틴마블이나 블랙팬서보다는 낫다는 생각이 들던데... \n진짜 보다가 잤음 노젬 돈 아까움 \n전 개인적으로 재밌게 봤습니다 1편보고 바로 보면 이해가 빠릅니다 \n초반에 원더우먼 고향씬만 좀 흥미진진하고 바로 지루해짐... 영화관에서 잔 적이 딱 2번인데 1번은 인터스텔라(이건 내가 빡대갈이라 이해를 못함) 다른 1번은 바로 이 영화 \n와...오.... 3번에걸쳐 겨우 끝까지 봤는데...내가 체력이 딸려서 졸린줄... 아직안봤으면 앵간하면 딴거보샘 \n움... 저에겐 안맞았던걸로.. \n갤 가돗의 원더우먼을 볼 수 있어서 넘 좋았습니다! 미국의 현 사태를 오마주하는 스토리가 정말 놀랍네요. 선과 악의 대결속에 선이 이기고 진실이 밝혀지길 기도합니다. Wonder Woman Forever♡ \n걍 기집년나와서 뭐하는것 같아보이니 평점 높은거보소 ㅋㅋ진짜 전작보다 퇴보한 쓰레기 영화임ㅋㅋ \n첫5분 전율 그자체ㅠ 영상, 액션 완전 훌륭했어요소~~~름 돋는 액션 \n캐비어로 맛대가리 없는 알탕을 끓였다DC는 반성해라저렇게 매력있는 캐릭터들로 C급 영화를 만드냐.능력이 안되면 마블 제작진에서 스카웃이라도 해라 \n나만 재밌게봄? 엄청 감동적이여서 눈물 질질 흘렷는데 \n첫장면부터 한시도 지루할틈없이 재밌게 봤어요 갤가돗 외모 실화인가요.. 완전여신이 따로없네요♥? \nThe truth is enough! \n이걸  돈주고  보는  호구   없지 ㅋㅋㅋ무료다운  보다가   말았다    어휴 \n선생님 수업시간이 따로없어요. 너무 졸렸어요. 밤에 잠 안올때 보면 딱! 딱! ~  딱 2 야! \n디시스럽다 ㅜ ㅜ 나만당할수없어! \n지금 현재의 소중함을 느끼길 수 있는 시간이 되었다. \n보던시간이 아까워 끝까지 본 영화..이거 돈내고 봤음 땅을 칠 뻔했음 \n감정 연기가 안되는 주연배우와 장르적 재미를 망각하고 타격감 없는 액션 연출과 성선설을 퍼트리려는 교훈에만 함몰된 스토리까지 합쳐진 총체적 난국의 하모니 \n여자 영웅이라 그런지 히어로의 내면갈등이 여태까지의 히어로물과는 다르게 색다른 맛이 있다. 긴 러닝타임 동안 지루하지 않도록 나름 다양한 연출과 긴장감을 집어 넣었다 \n세상에... 원더우먼에게 무슨짓을 한거야...몇번이나 뛰쳐 나가고 싶었지만 내가 나가면상영관에 홀로 남을 다른 관객분이 외로울까봐 꾹참았다..한줄요약 : 겔가돗은 이쁘고 영화는 못봐주겠다 \n히어로 영화는 평화,사랑 메세지를 담아서 사람들이 유치하다고 느낄 수 있다고 생각하지만 그 메세지가 지금 필요하다고 새각했다 다이애나가 대의를 위해 스티브랑 헤어지는 장면은 진짜 가슴아팠고 이번 편은 다이애나의 성장기라고 생각했다 배경이 밝아서 cg가 이질적인 느낌이 들었는지 아쉬운 점은 있었지만 따뜻하고 여운남는 영화였어서 다들 보고 판단했으면 좋겠다 \n중간까지는 나쁘지 않았어. 근데  후반부로 갈수록 내용이 ㅠㅠ 그리고 갑자기 연기도 ㅠㅠ. 갤 가돗님이 그렇게 못하는 연기가 아닌데 너무 보기 민망해지게 연출 연기 내용 모든면에서 학예회수준으로 변함. 마지막 20~30분 남기고 고민 많이함. 나갈까 버틸까. 버티는자가 패자 \n지루하고 유치하다. 1편후 기대했는데 실망이다. 둘이 헤어지는 장면만큼은 짠하긴 했다. \n돌아온 트레버에 포인트를 맞춘 탓인지 압도적인 힘이 강점인 원더우먼에게 붙인 빌런치곤 너무 심심하다 전작의 배경 스케일, 빌런과 비교한다면 더더욱... \n디씨 이렇게 능력있는 사람이 없나.. \n너무너무 유치....ㅋㅋㅋㅋ진짜 유치해요“소원을~말해봐~” \n엉성하고 엉성하다 역시 DC \n갤가돗, 크리스 파인 배우들의 연기를 좋아하시면 볼 수는 있어요. 근데 영화가 너무 별로였어요. 주연 배우 두명의 연기력과 레전드 카메오로 4점 드립니다. \n주인공만 예쁜 쓰레기에 가까운 결과물. DC가 DC했다. \n향수를 불러 일으키기에 충분하 영화 \n딱 하나, 감독이 하고자 하는 얘기에 집중해서 보면 불편하지 않습니다. 개연성 이런거 생각하고보면 졸작이지만 캐릭터는 전작을 잘 참고하여 만든듯하네요. 메세지 자체는 괜찬더라구요. \n슈퍼맨 보다 원더우먼이 더 재밌어요.아역배우 정말 잘하고~ 신기하게 너무 잘함액션장면이 길게 많이 안나와서 쪼매 실망했어도충분히 연기도 좋고 스토리는 좋았어요.영화 끝날때까지~ 긴장감은 연결되고 감동도 있고 좋았어요 \n저는 재밌게 봤어요~~ \n세련된 배우들과 올드하고 식상한 연출이 만들어낸 망작 \n액션 없는 원더우먼 말빨로 빌런 끝내버리기 원더우먼 1은 중간치는 했었는데 그것보다 못 하네 아.... \n너무 유치함 이게 영화냐 \n진짜 시간 남고 돈남아돌면 보세요....개연성이 너무 이상해서 집중도 안되고 갑자기??이걸?? 이런게 너무 많네요... 진짜 러닝타임은 왜이리 긴지 또;; \n이걸 영화라고 만든 제작사와 연출력도 없는 감독, 연기력도 없는데 액션도 못하는 배우의 삼위일체... \n아이고 전편에 비하면 많이 기대이하네요전개가 좀 어이없어요스토리도 난잡하고 주인공들 연기말고는 많이 실망스럽네요 여러가지 넣으려다 이도저도 아닌 상태가 된 듯 \n보고나서 여자감독이라는 말을 듣고 왜 여자여야만 했는지 알아차렸다. 여자에 의한 여자를 위한 여자의 영화 그래도 좋았다. \n네이버 평점이 낮아서 안보려다가 헌혈 사은품으로 영화관람권 받아서 봤는데, 의외로 괜찮았습니다 \n연출 정말 유치해서 영화보는내내 놀랐음... 연계성 연결성 떨어지는 설정들 ㅠ너무 실망했어요 마블이랑 비교되는건 어쩔수없다고 생각되네요영화배경이 굳이 1984여야되는 이유가 뭘까 생각하게 되구요그리고 후반부에 원더우먼이 하늘 날때 그래픽...정말 최악.. 그래픽 수준도 1984로 일부러 연출한건가 싶을 정도로 놀랐습니다액션은 볼만한데 스토리가 개연성없어요 좀심했어요.. \n보고 질질 짰어요 ㅠㅠ진실은 결국에는 이겨요ㅠㅠ원더우먼 사랑해요 ㅠㅠ \n갤가돗 액션여신 잼낫어요 \n왜 이 불경기에 나왔는지 알겠네.. 경쟁력이 없는거 자기들도 아는거지.. \nDC 는 마블을 따라갈 수 없다.  원더우 매력 말고는 남는게 없음 \n재밌게봄 왜케 평점이 낮은지 이해가 안가는데 갤가돗이 원더우먼에 정말 어울리는 배우인듯 \n이것이 히어로물의 80년대다 \n뭐랄까 린다카터를 다시본 놀라움?  주인공 이쁨?어설픔? \n꿀잼이에요 추천합니다. \n이 영화를 보기로한 소망을 취소한다 \n재밌게 봤어요~~ 사람이 너무 욕심을 부리면 큰 화를 입게 된다는 교훈을 얻게 되네요~ \n 스토리에 깊은 감명받음 \n음 생각 보다 재미 없고 지루하고 스토리도 별로다 사실 안보는걸 추천! \n와 대박 너무자서 집에서 못자겠다... \n진짜 1편봣던 기대감으로 보면 안됨 ㅋㅋ와 히어로 영화보면서 이렇게 재미없는거 처음봄 ... 개지루함 \n노ㅡ잼 진짜 모든 면에서 개노잼 \n원더우먼 피규어사러가야지원더우먼 겁나멋있쪄 \n혹평만 듣고 봐서 그런가 재밌었음 원더우먼 미모 탑 \n1편을 잼있게 봐서 나름 기대했었는데, 1편보다 못한 후속작이 되버렸습니다. 초중반까지는 뭔가 기대하게 만드는 흐름이었는데, 점점 맥락없이 전개되면서 DC특유의 재미없는 스토리와 그저그런 액션의 조합으로 끝났습니다. \n트럼프가 생각나네.. ㅎㅎ \n이걸보려고 그 세월을 기다린건가 존나 후회된다. 84년 배경소재에 레트로 음악도 예고 ...

# %%
from ckonlpy.tag import Twitter, Postprocessor

twitter = Twitter()
twitter.add_dictionary(['수어사이드스쿼드', '블랙팬서', '갤가돗', '갤 가돗', '개연성', '키스씬'], 'Noun')

stopwords = {'면서', '어요', '까지', '이건', '어서', '보지', '인지'}
replace = {'겔 가돗' : '갤가돗', '갤 가돗' : '갤가돗', '겔가돗' : '갤가돗'}
postprocessor = Postprocessor(twitter, replace = replace, stopwords = stopwords)

ls_pos = postprocessor.pos(txt)
# Out:
# C:\Users\dojun\anaconda3\envs\python38\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
ls_pos[:5]
# Out:
# [('탁', 'Noun'),
#  ('당', 'Suffix'),
#  ('이', 'Josa'),
#  ('More', 'Alpha'),
#  ('More', 'Alpha')]

# %%
ls_noun = []

for word, pos in ls_pos:
    if (len(word) > 1) & (pos == 'Noun'):
        ls_noun.append(word)

# %%
print(len(ls_noun))
ls_noun[:10]
# Out:
# 35857
# ['원더우먼', '대치', '수어', '사이드', '스쿼드', '엉덩이', '악몽', '대본', '연출', '마블']

# %%
from collections import Counter

counts = Counter(ls_noun)

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(font_path = 'C:\Windows\Fonts\HMKMRHD.TTF',
                     background_color = 'black',
                     width = 1000,
                     height = 1000,
                     max_font_size = 300)

img = wordcloud.generate_from_frequencies(counts)

plt.figure(figsize = (12, 12))
plt.imshow(img, interpolation = 'bilinear')
plt.axis('off')

plt.savefig('./py_data/wordcloud/원더우먼_워드클라우드.jpg')
plt.show()

# %%
counts = Counter(ls_noun)
counts_sorted = counts.most_common()

# %%
counts_sorted
# Out:
# [('영화', 1663),
#  ('원더우먼', 757),
#  ('액션', 686),
#  ('스토리', 585),
#  ('재미', 483),
#  ('히어로', 381),
#  ('진짜', 376),
#  ('기대', 337),
#  ('시간', 316),
#  ('그냥', 279),
#  ('갤가돗', 262),
#  ('생각', 259),
#  ('보고', 247),
#  ('정말', 230),
#  ('감독', 227),
#  ('연출', 192),
#  ('지루', 185),
#  ('감동', 183),
#  ('빌런', 183),
#  ('장면', 175),
#  ('개연성', 175),
#  ('마블', 174),
#  ('사람', 170),
#  ('느낌', 169),
#  ('최악', 169),
#  ('유치', 161),
#  ('소원', 160),
#  ('연기', 158),
#  ('정도', 156),
#  ('배우', 140),
#  ('실망', 140),
#  ('평점', 139),
#  ('별로', 132),
#  ('마지막', 130),
#  ('다가', 127),
#  ('하나', 124),
#  ('코로나', 122),
#  ('노잼', 116),
#  ('내용', 115),
#  ('처음', 112),
#  ('수준', 111),
#  ('영상', 104),
#  ('초반', 102),
#  ('전작', 99),
#  ('부분', 98),
#  ('역시', 97),
#  ('최고', 97),
#  ('중간', 95),
#  ('전개', 93),
#  ('사랑', 92),
#  ('주인공', 88),
#  ('년대', 86),
#  ('극장', 86),
#  ('작품', 82),
#  ('이나', 81),
#  ('슈퍼맨', 80),
#  ('조금', 78),
#  ('처럼', 77),
#  ('자체', 75),
#  ('부터', 75),
#  ('때문', 75),
#  ('매력', 74),
#  ('악당', 74),
#  ('보기', 74),
#  ('타임', 73),
#  ('전편', 73),
#  ('지금', 72),
#  ('세상', 72),
#  ('이상', 72),
#  ('디씨', 70),
#  ('영화관', 69),
#  ('쓰레기', 67),
#  ('교훈', 67),
#  ('여자', 67),
#  ('음악', 67),
#  ('여주', 67),
#  ('솔직', 67),
#  ('다시', 66),
#  ('오랜만', 66),
#  ('부족', 63),
#  ('이야기', 63),
#  ('그나', 63),
#  ('개봉', 63),
#  ('무슨', 62),
#  ('추천', 62),
#  ('이번', 61),
#  ('이유', 60),
#  ('려고', 60),
#  ('쿠키', 59),
#  ('진실', 58),
#  ('캐릭터', 57),
#  ('다이애나', 57),
#  ('드라마', 57),
#  ('필요', 56),
#  ('시작', 55),
#  ('지루함', 55),
#  ('모든', 54),
#  ('후반', 53),
#  ('크리스', 53),
#  ('뭔가', 53),
#  ('아무', 53),
#  ('메세지', 52),
#  ('영화인', 52),
#  ('화려', 52),
#  ('이해', 51),
#  ('완전', 51),
#  ('나름', 50),
#  ('인간', 49),
#  ('러닝', 49),
#  ('이하', 49),
#  ('내내', 49),
#  ('시대', 49),
#  ('한번', 48),
#  ('다른', 47),
#  ('결말', 47),
#  ('눈물', 46),
#  ('배경', 46),
#  ('억지', 46),
#  ('가지', 45),
#  ('신파', 45),
#  ('인적', 44),
#  ('루하', 44),
#  ('예고편', 44),
#  ('만하', 44),
#  ('더니', 44),
#  ('올해', 44),
#  ('로맨스', 43),
#  ('지고', 43),
#  ('아주', 43),
#  ('관객', 42),
#  ('아하', 42),
#  ('충분', 42),
#  ('편이', 42),
#  ('영웅', 41),
#  ('하늘', 41),
#  ('우리', 41),
#  ('감성', 41),
#  ('각하', 40),
#  ('감상', 40),
#  ('제발', 40),
#  ('치타', 40),
#  ('악역', 40),
#  ('여성', 40),
#  ('아름', 40),
#  ('년도', 40),
#  ('스티브', 39),
#  ('린다', 39),
#  ('가장', 39),
#  ('포기', 39),
#  ('만족', 39),
#  ('차라리', 39),
#  ('계속', 39),
#  ('요즘', 39),
#  ('갑자기', 38),
#  ('망작', 38),
#  ('이제', 38),
#  ('모두', 38),
#  ('몰입', 38),
#  ('메시지', 38),
#  ('상미', 38),
#  ('다운', 37),
#  ('위해', 37),
#  ('어도', 37),
#  ('절대', 37),
#  ('보시', 37),
#  ('남자', 37),
#  ('아들', 37),
#  ('전혀', 36),
#  ('건가', 36),
#  ('중반', 36),
#  ('대사', 36),
#  ('해도', 36),
#  ('대한', 36),
#  ('지도', 36),
#  ('다만', 36),
#  ('간만', 36),
#  ('능력', 35),
#  ('포인트', 35),
#  ('거지', 35),
#  ('욕심', 35),
#  ('이영화', 35),
#  ('제일', 35),
#  ('어가', 35),
#  ('볼거리', 35),
#  ('만큼', 35),
#  ('한스', 35),
#  ('짐머', 35),
#  ('크리스마스', 35),
#  ('미모', 34),
#  ('문제', 34),
#  ('무엇', 34),
#  ('확실', 34),
#  ('구나', 34),
#  ('설정', 33),
#  ('진심', 33),
#  ('일단', 33),
#  ('아가', 33),
#  ('역대', 33),
#  ('마무리', 33),
#  ('이정', 32),
#  ('기도', 32),
#  ('치하', 32),
#  ('갈수록', 32),
#  ('시국', 32),
#  ('주제', 32),
#  ('어이', 31),
#  ('모습', 31),
#  ('무비', 31),
#  ('물이', 31),
#  ('관람', 31),
#  ('수가', 31),
#  ('아쿠아', 31),
#  ('배트맨', 31),
#  ('캣츠', 31),
#  ('우먼', 30),
#  ('미국', 30),
#  ('동안', 30),
#  ('안보', 30),
#  ('기억', 30),
#  ('맥스', 30),
#  ('엉망', 30),
#  ('가족', 30),
#  ('까운', 29),
#  ('집중', 29),
#  ('다음', 29),
#  ('시리즈', 29),
#  ('웃음', 29),
#  ('영화로', 29),
#  ('보이', 29),
#  ('던데', 28),
#  ('연기력', 28),
#  ('그것', 28),
#  ('카터', 28),
#  ('소재', 28),
#  ('선택', 28),
#  ('제목', 28),
#  ('제대로', 28),
#  ('약간', 28),
#  ('바바라', 28),
#  ('킬링타임', 28),
#  ('여전', 28),
#  ('이지', 28),
#  ('알바', 28),
#  ('원더', 27),
#  ('체적', 27),
#  ('스케일', 27),
#  ('는걸', 27),
#  ('후회', 27),
#  ('황금', 27),
#  ('어디', 27),
#  ('도대체', 27),
#  ('의미', 26),
#  ('갑옷', 26),
#  ('이후', 26),
#  ('해주', 26),
#  ('기분', 26),
#  ('얼굴', 26),
#  ('서사', 26),
#  ('낭비', 26),
#  ('마음', 25),
#  ('욕망', 25),
#  ('거나', 25),
#  ('액션영화', 25),
#  ('시기', 25),
#  ('뜬금', 24),
#  ('해지', 24),
#  ('아이', 24),
#  ('화보', 24),
#  ('굳이', 24),
#  ('대하', 24),
#  ('인생', 24),
#  ('표현', 24),
#  ('만해', 24),
#  ('었다', 24),
#  ('전달', 24),
#  ('로드', 24),
#  ('상영', 24),
#  ('레트로', 23),
#  ('편의', 23),
#  ('래서', 23),
#  ('웅장', 23),
#  ('수도', 23),
#  ('각본', 23),
#  ('거리', 23),
#  ('줄거리', 23),
#  ('어색', 23),
#  ('매우', 23),
#  ('안타', 22),
#  ('감정', 22),
#  ('가슴', 22),
#  ('자기', 22),
#  ('옛날', 22),
#  ('자신', 22),
#  ('그게', 22),
#  ('마저', 22),
#  ('만화', 22),
#  ('어진', 22),
#  ('라서', 22),
#  ('연말', 22),
#  ('페드로', 22),
#  ('아쉬움', 22),
#  ('다소', 22),
#  ('시원', 22),
#  ('질질', 21),
#  ('분위기', 21),
#  ('인류', 21),
#  ('참고', 21),
#  ('런닝', 21),
#  ('대로', 21),
#  ('상황', 21),
#  ('오프닝', 21),
#  ('파스칼', 21),
#  ('흥미', 20),
#  ('퇴보', 20),
#  ('사실', 20),
#  ('전하', 20),
#  ('공감', 20),
#  ('페미', 20),
#  ('전부', 20),
#  ('크게', 20),
#  ('감사', 20),
#  ('저스티스리그', 19),
#  ('이기', 19),
#  ('주연', 19),
#  ('비교', 19),
#  ('졸작', 19),
#  ('거의', 19),
#  ('단순', 19),
#  ('희망', 19),
#  ('진부', 19),
#  ('평가', 19),
#  ('난방', 19),
#  ('추억', 19),
#  ('리뷰', 19),
#  ('행복', 19),
#  ('바로', 18),
#  ('외모', 18),
#  ('루즈', 18),
#  ('허경영', 18),
#  ('허무', 18),
#  ('중구', 18),
#  ('초딩', 18),
#  ('댓글', 18),
#  ('대체', 18),
#  ('우뢰매', 18),
#  ('시절', 18),
#  ('완성', 18),
#  ('이면', 18),
#  ('한편', 18),
#  ('간다', 17),
#  ('여서', 17),
#  ('긴장감', 17),
#  ('안나', 17),
#  ('아동', 17),
#  ('스타일', 17),
#  ('속편', 17),
#  ('아빠', 17),
#  ('진행', 17),
#  ('엔딩', 17),
#  ('한마디', 17),
#  ('점수', 17),
#  ('라면', 17),
#  ('조커', 17),
#  ('원래', 17),
#  ('전체', 17),
#  ('두시', 17),
#  ('헐리우드', 17),
#  ('기하', 17),
#  ('마스크', 17),
#  ('억지로', 17),
#  ('오락', 16),
#  ('도면', 16),
#  ('장르', 16),
#  ('레버', 16),
#  ('고자', 16),
#  ('남아', 16),
#  ('대박', 16),
#  ('명작', 16),
#  ('오지', 16),
#  ('점도', 16),
#  ('시나리오', 16),
#  ('언제', 16),
#  ('언니', 16),
#  ('임팩트', 16),
#  ('항상', 16),
#  ('원작', 16),
#  ('제작비', 16),
#  ('나중', 16),
#  ('노력', 16),
#  ('가요', 16),
#  ('화중', 16),
#  ('자동차극장', 16),
#  ('편도', 16),
#  ('살짝', 16),
#  ('알라딘', 16),
#  ('아직', 15),
#  ('헤어', 15),
#  ('얘기', 15),
#  ('런가', 15),
#  ('유의', 15),
#  ('파워', 15),
#  ('비중', 15),
#  ('이상하', 15),
#  ('리지', 15),
#  ('지나', 15),
#  ('음으로', 15),
#  ('형편', 15),
#  ('결론', 15),
#  ('라가', 15),
#  ('빈약', 15),
#  ('전형', 15),
#  ('대작', 15),
#  ('의문', 15),
#  ('완벽', 15),
#  ('니지', 15),
#  ('멜로', 15),
#  ('족하', 15),
#  ('반적', 15),
#  ('또한', 15),
#  ('스파이더맨', 15),
#  ('마이티', 15),
#  ('존재', 15),
#  ('설득', 14),
#  ('성하', 14),
#  ('드립', 14),
#  ('트럼프', 14),
#  ('다린', 14),
#  ('얼마나', 14),
#  ('슈퍼', 14),
#  ('스톤', 14),
#  ('오늘', 14),
#  ('아야', 14),
#  ('신파극', 14),
#  ('다리', 14),
#  ('인정', 14),
#  ('만점', 14),
#  ('나머지', 14),
#  ('덕분', 14),
#  ('머리', 14),
#  ('잘만', 14),
#  ('전투씬', 14),
#  ('소리', 14),
#  ('서도', 14),
#  ('뮤지컬', 14),
#  ('그닥', 14),
#  ('순간', 14),
#  ('강하', 14),
#  ('낫다', 13),
#  ('제작', 13),
#  ('상한', 13),
#  ('물의', 13),
#  ('소름', 13),
#  ('유니버스', 13),
#  ('설명', 13),
#  ('출연', 13),
#  ('분량', 13),
#  ('스나이더', 13),
#  ('과정', 13),
#  ('요소', 13),
#  ('는가', 13),
#  ('등장', 13),
#  ('오그', 13),
#  ('신도', 13),
#  ('하자', 13),
#  ('막판', 13),
#  ('지니', 13),
#  ('비행기', 13),
#  ('어간', 13),
#  ('블록버스터', 13),
#  ('혼자', 13),
#  ('조잡', 13),
#  ('싸움', 13),
#  ('여러', 13),
#  ('정의', 13),
#  ('인물', 13),
#  ('달리', 13),
#  ('이따', 13),
#  ('대안', 13),
#  ('스스로', 13),
#  ('분만', 13),
#  ('위로', 13),
#  ('예전', 13),
#  ('끝내', 12),
#  ('일부러', 12),
#  ('대감', 12),
#  ('점점', 12),
#  ('나은', 12),
#  ('동화', 12),
#  ('성장', 12),
#  ('하니', 12),
#  ('어린이', 12),
#  ('강추', 12),
#  ('퀄리티', 12),
#  ('중요', 12),
#  ('채찍', 12),
#  ('탐욕', 12),
#  ('섹시', 12),
#  ('로서', 12),
#  ('주제가', 12),
#  ('가면', 12),
#  ('여기', 12),
#  ('짜증', 12),
#  ('전투', 12),
#  ('공짜', 12),
#  ('밧줄', 12),
#  ('구성', 12),
#  ('편집', 12),
#  ('마치', 12),
#  ('재밋', 12),
#  ('역할', 12),
#  ('런들', 12),
#  ('여배우', 12),
#  ('말로', 11),
#  ('아보', 11),
#  ('디시', 11),
#  ('평화', 11),
#  ('고민', 11),
#  ('네이버', 11),
#  ('은지', 11),
#  ('후속작', 11),
#  ('저스티스', 11),
#  ('대충', 11),
#  ('이루', 11),
#  ('사건', 11),
#  ('코믹스', 11),
#  ('분명', 11),
#  ('누가', 11),
#  ('아이언맨', 11),
#  ('성인', 11),
#  ('효과', 11),
#  ('흥행', 11),
#  ('화가', 11),
#  ('개판', 11),
#  ('램프', 11),
#  ('미도', 11),
#  ('바람', 11),
#  ('반도', 11),
#  ('쇼핑몰', 11),
#  ('거짓', 11),
#  ('누구', 11),
#  ('원조', 11),
#  ('자리', 11),
#  ('남친', 11),
#  ('황당', 11),
#  ('심형래', 11),
#  ('판타지', 11),
#  ('기존', 11),
#  ('팔이', 11),
#  ('라지', 11),
#  ('우기', 11),
#  ('누나', 11),
#  ('캐리', 11),
#  ('진정', 11),
#  ('가치', 11),
#  ('사하', 11),
#  ('불가', 11),
#  ('오히려', 11),
#  ('몸매', 11),
#  ('무료', 10),
#  ('꿀잼', 10),
#  ('혹평', 10),
#  ('슈퍼히어로', 10),
#  ('여준', 10),
#  ('아해', 10),
#  ('오브', 10),
#  ('무조건', 10),
#  ('간반', 10),
#  ('최고다', 10),
#  ('여러분', 10),
#  ('평범', 10),
#  ('인상', 10),
#  ('일어', 10),
#  ('그거', 10),
#  ('달라', 10),
#  ('려면', 10),
#  ('거기', 10),
#  ('자꾸', 10),
#  ('가능', 10),
#  ('다크나이트', 10),
#  ('비행', 10),
#  ('부하', 10),
#  ('나이', 10),
#  ('마다', 10),
#  ('남성', 10),
#  ('의식', 10),
#  ('구로', 10),
#  ('정치', 10),
#  ('무재', 10),
#  ('철학', 10),
#  ('한국', 10),
#  ('하라', 10),
#  ('밸런스', 10),
#  ('의상', 10),
#  ('얼마', 10),
#  ('결과', 9),
#  ('고하', 9),
#  ('리기', 9),
#  ('의외', 9),
#  ('취소', 9),
#  ('흐름', 9),
#  ('타고', 9),
#  ('심지어', 9),
#  ('아마', 9),
#  ('클레멘타인', 9),
#  ('나기', 9),
#  ('손발', 9),
#  ('패티', 9),
#  ('총알', 9),
#  ('대가', 9),
#  ('박진', 9),
#  ('잡고', 9),
#  ('의심', 9),
#  ('사이', 9),
#  ('세계관', 9),
#  ('가족영화', 9),
#  ('존잼', 9),
#  ('단점', 9),
#  ('애매', 9),
#  ('세계', 9),
#  ('리그', 9),
#  ('상당', 9),
#  ('그대로', 9),
#  ('역량', 9),
#  ('다행', 9),
#  ('지지', 9),
#  ('티비', 9),
#  ('개재', 9),
#  ('휴먼', 9),
#  ('브루스', 9),
#  ('당하', 9),
#  ('현실', 9),
#  ('여운', 9),
#  ('에나', 9),
#  ('지구', 9),
#  ('충격', 9),
#  ('상적', 9),
#  ('팝콘', 9),
#  ('불면증', 9),
#  ('리하', 9),
#  ('맨오브스틸', 9),
#  ('어린시절', 9),
#  ('어른', 9),
#  ('잘못', 9),
#  ('사회', 9),
#  ('무하', 9),
#  ('서인', 9),
#  ('걱정', 9),
#  ('엄마', 9),
#  ('봉하', 9),
#  ('게다가', 9),
#  ('가득', 9),
#  ('고요', 9),
#  ('친구', 9),
#  ('작가', 8),
#  ('유아', 8),
#  ('기준', 8),
#  ('겨우', 8),
#  ('사태', 8),
#  ('반성', 8),
#  ('여신', 8),
#  ('불편', 8),
#  ('왜케', 8),
#  ('번개', 8),
#  ('아역', 8),
#  ('강력', 8),
#  ('당신', 8),
#  ('그녀', 8),
#  ('수퍼맨', 8),
#  ('라인', 8),
#  ('전개도', 8),
#  ('노답', 8),
#  ('드림', 8),
#  ('부자연', 8),
#  ('라다', 8),
#  ('한계', 8),
#  ('사운드', 8),
#  ('대상', 8),
#  ('었으', 8),
#  ('화면', 8),
#  ('최근', 8),
#  ('거르', 8),
#  ('주기', 8),
#  ('후기', 8),
#  ('한국영', 8),
#  ('자동차', 8),
#  ('소녀', 8),
#  ('적임', 8),
#  ('더욱', 8),
#  ('따름', 8),
#  ('도덕', 8),
#  ('잠깐', 8),
#  ('더라도', 8),
#  ('개인', 8),
#  ('대신', 8),
#  ('영하', 8),
#  ('구리', 8),
#  ('도입', 8),
#  ('심각', 8),
#  ('워너', 8),
#  ('하품', 8),
#  ('로만', 8),
#  ('도안', 8),
#  ('안해', 8),
#  ('평생', 8),
#  ('방법', 8),
#  ('날개', 8),
#  ('분동', 8),
#  ('자고', 8),
#  ('도로', 8),
#  ('리얼', 8),
#  ('애인', 8),
#  ('내시', 8),
#  ('이름', 8),
#  ('스크린', 8),
#  ('탄탄', 8),
#  ('대결', 8),
#  ('보석', 8),
#  ('러브스토리', 8),
#  ('요술', 8),
#  ('들보', 8),
#  ('지다', 8),
#  ('내년', 8),
#  ('미드', 7),
#  ('악의', 7),
#  ('한시', 7),
#  ('실화', 7),
#  ('대의', 7),
#  ('성장기', 7),
#  ('민망', 7),
#  ('말빨', 7),
#  ('날때', 7),
#  ('그래픽', 7),
#  ('독수리', 7),
#  ('학적', 7),
#  ('등등', 7),
#  ('악평', 7),
#  ('신선', 7),
#  ('초등학생', 7),
#  ('근래', 7),
#  ('쓸모', 7),
#  ('돌이', 7),
#  ('요정', 7),
#  ('테러', 7),
#  ('과거', 7),
#  ('고도', 7),
#  ('자연', 7),
#  ('주의', 7),
#  ('마셈', 7),
#  ('평이', 7),
#  ('캐스팅', 7),
#  ('성공', 7),
#  ('메인', 7),
#  ('지게', 7),
#  ('피해', 7),
#  ('어보', 7),
#  ('강조', 7),
#  ('혹시', 7),
#  ('설마', 7),
#  ('통해', 7),
#  ('장하', 7),
#  ('포함', 7),
#  ('아지', 7),
#  ('개도', 7),
#  ('전세계', 7),
#  ('게임', 7),
#  ('만듬', 7),
#  ('무시', 7),
#  ('긴장', 7),
#  ('미래', 7),
#  ('한숨', 7),
#  ('몇몇', 7),
#  ('이상은', 7),
#  ('브루', 7),
#  ('구원', 7),
#  ('어마', 7),
#  ('막장', 7),
#  ('기만', 7),
#  ('고양이', 7),
#  ('파워레인저', 7),
#  ('해결', 7),
#  ('장난', 7),
#  ('세기', 7),
#  ('점주', 7),
#  ('숙면', 7),
#  ('탄생', 7),
#  ('마냥', 7),
#  ('아마존', 7),
#  ('카리스마', 7),
#  ('보라', 7),
#  ('직하', 7),
#  ('연속', 7),
#  ('괴물', 7),
#  ('반전', 7),
#  ('어벤져스', 7),
#  ('화끈', 7),
#  ('보신', 7),
#  ('투명', 7),
#  ('성적', 7),
#  ('감탄', 7),
#  ('기본', 7),
#  ('고생', 7),
#  ('정신', 7),
#  ('예상', 7),
#  ('상상', 7),
#  ('아저씨', 7),
#  ('양심', 7),
#  ('커플', 7),
#  ('이웃', 7),
#  ('보람', 7),
#  ('코미디', 7),
#  ('누님', 7),
#  ('그때', 7),
#  ('전쟁', 7),
#  ('대치', 6),
#  ('탄하', 6),
#  ('샤잠', 6),
#  ('캡틴마블', 6),
#  ('흥미진진', 6),
#  ('번은', 6),
#  ('현재', 6),
#  ('갈등', 6),
#  ('요약', 6),
#  ('요하', 6),
#  ('부로', 6),
#  ('도적', 6),
#  ('향수', 6),
#  ('이도', 6),
#  ('상태', 6),
#  ('여야', 6),
#  ('감명', 6),
#  ('존나', 6),
#  ('올가미', 6),
#  ('지면', 6),
#  ('납득', 6),
#  ('소녀시대', 6),
#  ('더라면', 6),
#  ('나라', 6),
#  ('이용', 6),
#  ('이별', 6),
#  ('최선', 6),
#  ('디즈니', 6),
#  ('와중', 6),
#  ('데리', 6),
#  ('바닥', 6),
#  ('수면제', 6),
#  ('유일', 6),
#  ('어거지', 6),
#  ('굿굿', 6),
#  ('신의', 6),
#  ('구림', 6),
#  ('당황', 6),
#  ('기전', 6),
#  ('활약', 6),
#  ('간이', 6),
#  ('호불호', 6),
#  ('듭니', 6),
#  ('예술', 6),
#  ('혼란', 6),
#  ('디워', 6),
#  ('깊이', 6),
#  ('두운', 6),
#  ('대화', 6),
#  ('배경음악', 6),
#  ('아내', 6),
#  ('유명', 6),
#  ('역활', 6),
#  ('대부분', 6),
#  ('사라', 6),
#  ('대중', 6),
#  ('응원', 6),
#  ('황금박쥐', 6),
#  ('졸림', 6),
#  ('복고', 6),
#  ('실패', 6),
#  ('노래', 6),
#  ('따위', 6),
#  ('스올', 6),
#  ('인형', 6),
#  ('스트레스', 6),
#  ('박수', 6),
#  ('제외', 6),
#  ('과연', 6),
#  ('야만', 6),
#  ('추가', 6),
#  ('애니메이션', 6),
#  ('로맨틱', 6),
#  ('보이지', 6),
#  ('유일하', 6),
#  ('반개', 6),
#  ('행동', 6),
#  ('조차', 6),
#  ('재앙', 6),
#  ('워낙', 6),
#  ('스토리텔링', 6),
#  ('사용', 6),
#  ('헐리웃', 6),
#  ('아예', 6),
#  ('다그', 6),
#  ('이집트', 6),
#  ('서커스', 6),
#  ('삼류', 6),
#  ('바란', 6),
#  ('우리나라', 6),
#  ('정작', 6),
#  ('수퍼', 6),
#  ('파괴', 6),
#  ('증명', 6),
#  ('애기', 6),
#  ('티켓', 6),
#  ('은영', 6),
#  ('선물', 6),
#  ('부시', 6),
#  ('어찌', 6),
#  ('서로', 6),
#  ('수록', 6),
#  ('제로', 6),
#  ('마법', 6),
#  ('활용', 6),
#  ('었습니', 6),
#  ('외치', 6),
#  ('타인', 6),
#  ('다한', 6),
#  ('본인', 6),
#  ('그라드', 6),
#  ('인의', 6),
#  ('작정', 6),
#  ('신기', 6),
#  ('중하', 6),
#  ('열심', 6),
#  ('부족함', 6),
#  ('답답', 6),
#  ('구도', 6),
#  ('시퀀스', 6),
#  ('접함', 6),
#  ('구해', 6),
#  ('산만', 6),
#  ('고통', 6),
#  ('보임', 6),
#  ('이전', 6),
#  ('호강', 6),
#  ('여자친구', 6),
#  ('방역', 6),
#  ('최종', 6),
#  ('수어', 5),
#  ('사이드', 5),
#  ('보통', 5),
#  ('깝습니', 5),
#  ('내면', 5),
#  ('몇번', 5),
#  ('기고', 5),
#  ('레전드', 5),
#  ('연결', 5),
#  ('세련', 5),
#  ('코스', 5),
#  ('치면', 5),
#  ('거짓말', 5),
#  ('나치', 5),
#  ('그린랜턴', 5),
#  ('배대슈', 5),
#  ('러브', 5),
#  ('허무맹랑', 5),
#  ('앞뒤', 5),
#  ('감기', 5),
#  ('완젼', 5),
#  ('입장', 5),
#  ('비판', 5),
#  ('갈리', 5),
#  ('명대사', 5),
#  ('감흥', 5),
#  ('정확', 5),
#  ('때매', 5),
#  ('어처구니', 5),
#  ('그다지', 5),
#  ('젠킨스', 5),
#  ('감고', 5),
#  ('주네', 5),
#  ('인지도', 5),
#  ('만도', 5),
#  ('기적', 5),
#  ('특수', 5),
#  ('치가', 5),
#  ('마사', 5),
#  ('이란', 5),
#  ('내기', 5),
#  ('커서', 5),
#  ('적절', 5),
#  ('만드', 5),
#  ('한지', 5),
#  ('진창', 5),
#  ('유튜브', 5),
#  ('상하', 5),
#  ('꿀잠', 5),
#  ('빌어', 5),
#  ('애가', 5),
#  ('쉴드', 5),
#  ('무리', 5),
#  ('대고', 5),
#  ('하나요', 5),
#  ('최강', 5),
#  ('자아', 5),
#  ...]

# %%
df_count = pd.DataFrame(counts_sorted, columns = ['단어', '빈도수'])
df_count
# Out:
#         단어   빈도수
# 0       영화  1663
# 1     원더우먼   757
# 2       액션   686
# 3      스토리   585
# 4       재미   483
# ...    ...   ...
# 5261    고서     1
# 5262  와일드캣     1
# 5263    수확     1
# 5264    냄새     1
# 5265    정합     1
#
# [5266 rows x 2 columns]

# %%
df_count.to_csv('./py_data/wordcloud/원더우먼_단어빈도수.csv', index=False, encoding = 'euc-kr')

# %%
df_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5266 entries, 0 to 5265
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   단어      5266 non-null   object
#  1   빈도수     5266 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 82.4+ KB

# %%
df= df_count.astype({'빈도수':'int32'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5266 entries, 0 to 5265
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   단어      5266 non-null   object
#  1   빈도수     5266 non-null   int32
# dtypes: int32(1), object(1)
# memory usage: 61.8+ KB

# %% [markdown]
# # Groupby

# %%
import pandas as pd

df = pd.read_excel('./py_data/crawling/원더우먼_리뷰.xlsx', engine = 'openpyxl')
df.head()
# Out:
#           날짜  점수                                                 댓글
# 0 2021-01-19   4  탁당이 More More하면서 원더우먼과 대치할때 수어사이드 스쿼드의 엉덩이 춤의 ...
# 1 2021-01-19   1                                         DC가 DC했다.
# 2 2021-01-19   1  원더 우먼이라는 캐릭터 자체가 별다른 매력없이 소비되고, 흥미롭게 시작하는 첫부분은...
# 3 2021-01-19  10  오락영화가 이정도면 괜찮을듯한데... 스토리도 괜찮았음.  갤가돗은 예뻤고.. 마블...
# 4 2021-01-19   1                                진짜 보다가 잤음 노젬 돈 아까움

# %%
df_mean = df.groupby('날짜').mean()
df_mean.head(10)
# Out:
#                    점수
# 날짜
# 2019-10-10  10.000000
# 2019-10-12  10.000000
# 2019-10-18  10.000000
# 2020-12-23   6.925234
# 2020-12-24   6.294294
# 2020-12-25   5.464037
# 2020-12-26   5.583120
# 2020-12-27   5.262500
# 2020-12-28   4.886792
# 2020-12-29   4.908745

# %%
df_mean = df_mean[3:]

# %% [markdown]
# # 그래프 출력

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname='C:\Windows\Fonts\malgunbd.ttf').get_name()
rc('font', family = font_name)

df_mean.plot(figsize = (15, 5))
plt.savefig('./py_data/wordcloud/원더우먼_빈도그래프.jpg')
plt.show()
